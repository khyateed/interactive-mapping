# %% [markdown]
# # Vizualizing National Prison Demographics by County
# #### By Khyatee Desai<br>Oct. 13, 2020
# ## Data Sources:
# https://www.prisonpolicy.org/racialgeography/counties.html

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# with open('scraped_data.html', 'w') as writer:
#     writer.write(requests.get("https://www.prisonpolicy.org/racialgeography/counties.html").text)

# %%
with open('scraped_data.html', 'r') as page:
    soup = BeautifulSoup(page, 'html.parser')

# %% [markdown]
# ### Parse through the html using BeautifulSoup, and create a list of lists containing the table data

# %%
table=[]
row=[]
for col in soup.find('tr').findAll('th'):
    row.append(col.text)
table.append(row)

for line in soup.findAll('tr')[1:]:
    row=[]
    for col in line.findAll('td'):
        row.append(col.text)
    table.append(row)
print(table[:10])
# Out:
# [['County', 'State', 'Total Population', 'Total White Population', 'Total Black Population', 'Total Latino Population', 'Incarcerated Population', 'Incarcerated White Population', 'Incarcerated Black Population', 'Incarcerated Latino Population', 'Non-incarcerated Population', 'Non-incarcerated White Population', 'Non-Incarcerated Black Population', 'Non-Incarcerated Latino Population', 'Ratio of Overrepresentation of Whites Incarcerated Compared to Whites Non-Incarcerated', 'Ratio of Overrepresentation of Blacks Incarcerated Compared to Blacks Non-Incarcerated', 'Ratio of Overrepresentation of Latinos Incarcerated Compared to Latinos Non-Incarcerated'], ['Autauga County', 'Alabama', '54,571', '42,154', '9,643', '1,310', '181', '71', '80', '31', '54,390', '42,083', '9,563', '1,279', '0.51', '2.51', '7.29'], ['Baldwin County', 'Alabama', '182,265', '152,200', '17,105', '7,992', '1,050', '530', '513', '5', '181,215', '151,670', '16,592', '7,987', '0.6', '5.33', '0.11'], ['Barbour County', 'Alabama', '27,457', '12,837', '12,875', '1,387', '3,044', '1,200', '1,794', '23', '24,413', '11,637', '11,081', '1,364', '0.83', '1.3', '0.14'], ['Bibb County', 'Alabama', '22,915', '17,191', '5,047', '406', '2,007', '595', '1,357', '54', '20,908', '16,596', '3,690', '352', '0.37', '3.83', '1.6'], ['Blount County', 'Alabama', '57,322', '50,952', '761', '4,626', '129', '118', '6', '5', '57,193', '50,834', '755', '4,621', '1.03', '3.52', '0.48'], ['Bullock County', 'Alabama', '10,914', '2,392', '7,666', '777', '1,528', '605', '915', '4', '9,386', '1,787', '6,751', '773', '2.08', '0.83', '0.03'], ['Butler County', 'Alabama', '20,947', '11,324', '9,095', '191', '38', '10', '27', '0', '20,909', '11,314', '9,068', '191', '0.49', '1.64', '0'], ['Calhoun County', 'Alabama', '118,572', '87,285', '24,382', '3,893', '469', '256', '194', '14', '118,103', '87,029', '24,188', '3,879', '0.74', '2.02', '0.91'], ['Chambers County', 'Alabama', '34,215', '19,893', '13,257', '536', '137', '74', '62', '1', '34,078', '19,819', '13,195', '535', '0.93', '1.17', '0.46']]

# %% [markdown]
# ### Create a Pandas DataFrame from the parsed data

# %%
df = pd.DataFrame(table)
df.head()
# Out:
#                0        1                 2                       3   \
# 0          County    State  Total Population  Total White Population
# 1  Autauga County  Alabama            54,571                  42,154
# 2  Baldwin County  Alabama           182,265                 152,200
# 3  Barbour County  Alabama            27,457                  12,837
# 4     Bibb County  Alabama            22,915                  17,191
#
#                        4                        5                        6   \
# 0  Total Black Population  Total Latino Population  Incarcerated Population
# 1                   9,643                    1,310                      181
# 2                  17,105                    7,992                    1,050
# 3                  12,875                    1,387                    3,044
# 4                   5,047                      406                    2,007
#
#                               7                              8   \
# 0  Incarcerated White Population  Incarcerated Black Population
# 1                             71                             80
# 2                            530                            513
# 3                          1,200                          1,794
# 4                            595                          1,357
#
#                                9                            10  \
# 0  Incarcerated Latino Population  Non-incarcerated Population
# 1                              31                       54,390
# 2                               5                      181,215
# 3                              23                       24,413
# 4                              54                       20,908
#
#                                   11                                 12  \
# 0  Non-incarcerated White Population  Non-Incarcerated Black Population
# 1                             42,083                              9,563
# 2                            151,670                             16,592
# 3                             11,637                             11,081
# 4                             16,596                              3,690
#
#                                    13  \
# 0  Non-Incarcerated Latino Population
# 1                               1,279
# 2                               7,987
# 3                               1,364
# 4                                 352
#
#                                                   14  \
# 0  Ratio of Overrepresentation of Whites Incarcer...
# 1                                               0.51
# 2                                                0.6
# 3                                               0.83
# 4                                               0.37
#
#                                                   15  \
# 0  Ratio of Overrepresentation of Blacks Incarcer...
# 1                                               2.51
# 2                                               5.33
# 3                                                1.3
# 4                                               3.83
#
#                                                   16
# 0  Ratio of Overrepresentation of Latinos Incarce...
# 1                                               7.29
# 2                                               0.11
# 3                                               0.14
# 4                                                1.6

# %% [markdown]
# ### Data Cleaning
# Renaming columns, imputing Null values, removing commas, changing data types, yada yada

# %%
# Set first column as headers, drop unnecessary columns
df.columns = df.iloc[0]
df = df.iloc[1:]
df.drop(index= 2782, inplace=True)
df.rename(columns={'Ratio of Overrepresentation of Whites Incarcerated Compared to Whites Non-Incarcerated':'White Overrepresentation', 'Ratio of Overrepresentation of Blacks Incarcerated Compared to Blacks Non-Incarcerated': 'Black Overrepresentation', 'Ratio of Overrepresentation of Latinos Incarcerated Compared to Latinos Non-Incarcerated':'Latino Overrepresentation'}, inplace=True)

# %%
# Replace text 'NA' values with zeros
df['Black Overrepresentation'] = df['Black Overrepresentation'].str.replace('NA', '0')
df['Latino Overrepresentation'] = df['Latino Overrepresentation'].str.replace('NA', '0')

# %%
# Remove commas and change datatypes to floats
for col in df.columns[2:]:
    try:
        df[col] = df[col].str.replace(',', '').astype(float)
    except:
        pass
df.dtypes
# Out:
# 0
# County                                 object
# State                                  object
# Total Population                      float64
# Total White Population                float64
# Total Black Population                float64
# Total Latino Population               float64
# Incarcerated Population               float64
# Incarcerated White Population         float64
# Incarcerated Black Population         float64
# Incarcerated Latino Population        float64
# Non-incarcerated Population           float64
# Non-incarcerated White Population     float64
# Non-Incarcerated Black Population     float64
# Non-Incarcerated Latino Population    float64
# White Overrepresentation              float64
# Black Overrepresentation              float64
# Latino Overrepresentation             float64
# dtype: object

# %%
df.sample(5)
# Out:
# 0             County       State  Total Population  Total White Population  \
# 234    Solano County  California          413344.0                168628.0
# 2569    Comal County       Texas          108472.0                 77387.0
# 1193     York County       Maine          197131.0                188422.0
# 924   Greeley County      Kansas            1247.0                  1056.0
# 2173    Logan County    Oklahoma           41848.0                 32864.0
#
# 0     Total Black Population  Total Latino Population  \
# 234                  60750.0                  99356.0
# 2569                  1727.0                  26989.0
# 1193                  1108.0                   2478.0
# 924                      6.0                    171.0
# 2173                  3804.0                   2170.0
#
# 0     Incarcerated Population  Incarcerated White Population  \
# 234                    8766.0                         2397.0
# 2569                    279.0                          177.0
# 1193                    207.0                          184.0
# 924                       0.0                            0.0
# 2173                      0.0                            0.0
#
# 0     Incarcerated Black Population  Incarcerated Latino Population  \
# 234                          3735.0                          1786.0
# 2569                           25.0                            76.0
# 1193                           13.0                             4.0
# 924                             0.0                             0.0
# 2173                            0.0                             0.0
#
# 0     Non-incarcerated Population  Non-incarcerated White Population  \
# 234                      404578.0                           166231.0
# 2569                     108193.0                            77210.0
# 1193                     196924.0                           188238.0
# 924                        1247.0                             1056.0
# 2173                      41848.0                            32864.0
#
# 0     Non-Incarcerated Black Population  Non-Incarcerated Latino Population  \
# 234                             57015.0                             97570.0
# 2569                             1702.0                             26913.0
# 1193                             1095.0                              2474.0
# 924                                 6.0                               171.0
# 2173                             3804.0                              2170.0
#
# 0     White Overrepresentation  Black Overrepresentation  \
# 234                       0.67                      3.02
# 2569                      0.89                      5.71
# 1193                      0.93                     11.21
# 924                       0.00                      0.00
# 2173                      0.00                      0.00
#
# 0     Latino Overrepresentation
# 234                        0.84
# 2569                       1.10
# 1193                       1.53
# 924                        0.00
# 2173                       0.00

# %%
fig= plt.figure(figsize=(7,7))

plt.plot(df['Black Overrepresentation'], color='red');
plt.plot(df['Latino Overrepresentation'], color='orange');
plt.plot(df['White Overrepresentation'], color='blue');

# %%
grouped = df.groupby('State')[['White Overrepresentation', 'Black Overrepresentation', 'Latino Overrepresentation']].mean().sort_values('Black Overrepresentation',ascending=False)

fig= plt.figure(figsize=(14,10));
plt.bar(x=grouped.index, height=grouped['Black Overrepresentation'], color='purple');
plt.bar(x=grouped.index, height=grouped['Latino Overrepresentation'], color='blue');
plt.bar(x=grouped.index, height=grouped['White Overrepresentation'], color='pink');
plt.xticks(rotation=75);

# %%
df.sort_values('Black Overrepresentation', ascending=False).head(5)
# Out:
# 0             County     State  Total Population  Total White Population  \
# 2782  Daggett County      Utah            1059.0                  1000.0
# 1073   Martin County  Kentucky           12929.0                 11533.0
# 2161   Harper County  Oklahoma            3685.0                  2957.0
# 626    Greene County  Illinois           13886.0                 13517.0
# 691     Wayne County  Illinois           16760.0                 16340.0
#
# 0     Total Black Population  Total Latino Population  \
# 2782                     4.0                     33.0
# 1073                   896.0                    388.0
# 2161                     3.0                    645.0
# 626                    119.0                    115.0
# 691                     42.0                    176.0
#
# 0     Incarcerated Population  Incarcerated White Population  \
# 2782                     63.0                           46.0
# 1073                   1579.0                          327.0
# 2161                      4.0                            2.0
# 626                     203.0                           86.0
# 691                       2.0                            0.0
#
# 0     Incarcerated Black Population  Incarcerated Latino Population  \
# 2782                            4.0                             8.0
# 1073                          884.0                           340.0
# 2161                            1.0                             0.0
# 626                           102.0                            14.0
# 691                             2.0                             2.0
#
# 0     Non-incarcerated Population  Non-incarcerated White Population  \
# 2782                        996.0                              954.0
# 1073                      11350.0                            11206.0
# 2161                       3681.0                             2955.0
# 626                       13683.0                            13431.0
# 691                       16758.0                            16340.0
#
# 0     Non-Incarcerated Black Population  Non-Incarcerated Latino Population  \
# 2782                                0.0                                25.0
# 1073                               12.0                                48.0
# 2161                                2.0                               645.0
# 626                                17.0                               101.0
# 691                                40.0                               174.0
#
# 0     White Overrepresentation  Black Overrepresentation  \
# 2782                      0.76                       inf
# 1073                      0.21                    508.95
# 2161                      0.62                    500.00
# 626                       0.43                    418.72
# 691                       0.00                    416.67
#
# 0     Latino Overrepresentation
# 2782                       5.06
# 1073                      51.27
# 2161                       0.00
# 626                        9.32
# 691                       96.15
